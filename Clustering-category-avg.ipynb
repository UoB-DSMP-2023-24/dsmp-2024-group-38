# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns
import hdbscan 
from sklearn.cluster import DBSCAN

# %%
fake_transaction = pd.read_csv('fake_transactional_data_24.csv')

# %%
new_categories = pd.read_excel('/Users/blackrose/Desktop/dsmp-2024-group-38/finalised_merchant_categories.xlsx')

groups = new_categories.columns
category_account_pairs = []
for group in groups:
    businesses = new_categories[group].dropna().apply(lambda x: x.strip("'"))
    for business in businesses:
        category_account_pairs.append({'business': business, 'group': group})

category_df = pd.DataFrame(category_account_pairs)

# %%
per_category = fake_transaction.merge(category_df, left_on='to_randomly_generated_account', right_on='business', how='left')
per_category.drop(['business'], axis=1, inplace=True)
per_category.dropna(inplace=True)
per_category
# Out:
#           from_totally_fake_account  monopoly_money_amount  \
# 0                           10371.0                   4.00
# 3                           18555.0                   4.10
# 5                           18555.0                   4.45
# 6                           18555.0                   1.45
# 7                           18555.0                   5.00
# ...                             ...                    ...
# 10148274                    81404.0                   1.80
# 10148275                    32185.0                   2.65
# 10148276                    32185.0                   2.45
# 10148277                    57569.0                  14.00
# 10148279                    53444.0                   2.65
#
#          to_randomly_generated_account not_happened_yet_date   group
# 0                               CINEMA            01/01/2025  Cinema
# 3                  HIPSTER_COFFEE_SHOP            01/01/2025    Café
# 5           TOTALLY_A_REAL_COFFEE_SHOP            01/01/2025    Café
# 6                          COFFEE_SHOP            01/01/2025    Café
# 7                                 CAFE            01/01/2025    Café
# ...                                ...                   ...     ...
# 10148274    TOTALLY_A_REAL_COFFEE_SHOP            31/12/2025    Café
# 10148275                   COFFEE_SHOP            31/12/2025    Café
# 10148276                   COFFEE_SHOP            31/12/2025    Café
# 10148277                      WINE_BAR            31/12/2025     Bar
# 10148279           A_LOCAL_COFFEE_SHOP            31/12/2025    Café
#
# [7494372 rows x 5 columns]

# %%
per_category = per_category.pivot_table(index='from_totally_fake_account',
                                columns='group',
                                values='monopoly_money_amount',
                                aggfunc='mean')

per_category.head(20)
# Out:
# group                      Accessory shop  Alcohol Store        Bar  \
# from_totally_fake_account
# 1000.0                                NaN      38.326667  11.895753
# 1002.0                                NaN      51.656667  11.846698
# 1006.0                                NaN      21.590000  11.776316
# 1018.0                                NaN      19.995000   5.955986
# 1053.0                                NaN      59.990000  11.774510
# 1059.0                                NaN      10.000000  12.035294
# 1071.0                                NaN      36.990000   6.470370
# 1078.0                                NaN      16.995000  12.070621
# 1086.0                                NaN      56.790000   5.773529
# 1087.0                                NaN      29.990000  12.090734
# 1113.0                                NaN      10.000000  11.734513
# 1120.0                                NaN      21.656667   5.423875
# 1122.0                                NaN      24.245000  11.645833
# 1125.0                                NaN      34.991667  10.804455
# 1133.0                                NaN      30.990000   7.841121
# 1142.0                                NaN      22.996667  11.642066
# 1174.0                                NaN      14.995000  11.974684
# 1179.0                                NaN      36.660000  11.684549
# 1180.0                                NaN      15.245000  11.335249
# 1186.0                                NaN            NaN  11.254980
#
# group                      Bookstore    Butcher      Café   Children  \
# from_totally_fake_account
# 1000.0                      8.000000        NaN  2.404920  80.000000
# 1002.0                           NaN        NaN  2.348301  67.000000
# 1006.0                     11.444444  21.800000  2.428012  59.200000
# 1018.0                     10.000000  26.000000  2.507692  59.000000
# 1053.0                           NaN  18.000000  2.688333  33.250000
# 1059.0                     10.434783        NaN  2.392663  50.764706
# 1071.0                     17.500000  30.000000  2.473515  13.000000
# 1078.0                           NaN  15.923077  2.397773  49.642857
# 1086.0                           NaN        NaN  2.470244  52.045455
# 1087.0                      7.000000        NaN  2.447219  55.500000
# 1113.0                           NaN  15.166667  2.540302  68.000000
# 1120.0                           NaN        NaN  2.390330  57.142857
# 1122.0                           NaN        NaN  2.501594  53.619048
# 1125.0                     11.708333        NaN  2.363702        NaN
# 1133.0                     15.000000  17.111111  2.848491        NaN
# 1142.0                     13.794118  17.250000  2.270000  51.000000
# 1174.0                     10.877551        NaN  2.394749  38.600000
# 1179.0                           NaN  33.000000  2.471901        NaN
# 1180.0                     12.700000        NaN  2.469697        NaN
# 1186.0                     13.321429  15.571429  2.422955  94.000000
#
# group                        Cinema  Clothing store   Cookshop  ...   Gym  \
# from_totally_fake_account                                       ...
# 1000.0                     6.146341      145.000000        NaN  ...   NaN
# 1002.0                     6.180000             NaN        NaN  ...   NaN
# 1006.0                     5.820513       65.000000  16.555556  ...   NaN
# 1018.0                     5.600000      118.176471        NaN  ...   NaN
# 1053.0                     6.166667      111.347826        NaN  ...   NaN
# 1059.0                     4.000000      128.000000        NaN  ...   NaN
# 1071.0                     6.968750             NaN  23.000000  ...  20.0
# 1078.0                     6.523810             NaN  13.333333  ...   NaN
# 1086.0                     6.243902      116.600000        NaN  ...   NaN
# 1087.0                     4.750000       53.000000  25.000000  ...   NaN
# 1113.0                          NaN       75.000000  20.600000  ...   NaN
# 1120.0                     4.500000      142.000000   8.000000  ...   NaN
# 1122.0                          NaN             NaN        NaN  ...   NaN
# 1125.0                     5.500000             NaN  11.000000  ...  20.0
# 1133.0                     6.179487       87.000000  16.090909  ...   NaN
# 1142.0                     6.500000             NaN  15.857143  ...   NaN
# 1174.0                     5.857143      163.000000        NaN  ...   NaN
# 1179.0                     6.500000      127.000000        NaN  ...   NaN
# 1180.0                     6.709677      100.150000        NaN  ...   NaN
# 1186.0                          NaN      147.000000  17.000000  ...   NaN
#
# group                          Home        Pets        Pub  \
# from_totally_fake_account
# 1000.0                     46.500000  25.190476  15.157426
# 1002.0                           NaN        NaN  16.369496
# 1006.0                     44.000000        NaN  15.574400
# 1018.0                     71.000000  30.000000   6.400000
# 1053.0                     42.454545        NaN  13.153661
# 1142.0                                  NaN
# 1174.0                                  NaN
# 1179.0                                  NaN
# 1180.0                                  NaN
# 1186.0                                  NaN
#
# [20 rows x 25 columns]

# %% [markdown]
# Replace NaNs where people haven't spent money to 0.

# %%
per_category = per_category.fillna(0)
per_category.head(10)
# Out:
# group                      Accessory shop  Alcohol Store        Bar  \
# from_totally_fake_account
# 1000.0                                0.0      38.326667  11.895753
# 1002.0                                0.0      51.656667  11.846698
# 1006.0                                0.0      21.590000  11.776316
# 1018.0                                0.0      19.995000   5.955986
# 1053.0                                0.0      59.990000  11.774510
# 1059.0                                0.0      10.000000  12.035294
# 1071.0                                0.0      36.990000   6.470370
# 1078.0                                0.0      16.995000  12.070621
# 1086.0                                0.0      56.790000   5.773529
# 1087.0                                0.0      29.990000  12.090734
#
# group                      Bookstore    Butcher      Café   Children  \
# from_totally_fake_account
# 1000.0                      8.000000   0.000000  2.404920  80.000000
# 1002.0                      0.000000   0.000000  2.348301  67.000000
# 1006.0                     11.444444  21.800000  2.428012  59.200000
# 1018.0                     10.000000  26.000000  2.507692  59.000000
# 1053.0                      0.000000  18.000000  2.688333  33.250000
# 1059.0                     10.434783   0.000000  2.392663  50.764706
# 1071.0                     17.500000  30.000000  2.473515  13.000000
# 1078.0                      0.000000  15.923077  2.397773  49.642857
# 1086.0                      0.000000   0.000000  2.470244  52.045455
# 1087.0                      7.000000   0.000000  2.447219  55.500000
#
# group                        Cinema  Clothing store   Cookshop  ...   Gym  \
# from_totally_fake_account                                       ...
# 1000.0                     6.146341      145.000000   0.000000  ...   0.0
# 1002.0                     6.180000        0.000000   0.000000  ...   0.0
# 1006.0                     5.820513       65.000000  16.555556  ...   0.0
# 1018.0                     5.600000      118.176471   0.000000  ...   0.0
# 1053.0                     6.166667      111.347826   0.000000  ...   0.0
# 1059.0                     4.000000      128.000000   0.000000  ...   0.0
# 1071.0                     6.968750        0.000000  23.000000  ...  20.0
# 1078.0                     6.523810        0.000000  13.333333  ...   0.0
# 1086.0                     6.243902      116.600000   0.000000  ...   0.0
# 1087.0                     4.750000       53.000000  25.000000  ...   0.0
#
# group                          Home        Pets        Pub  \
# from_totally_fake_account
# 1000.0                     46.500000  25.190476  15.157426
# 1002.0                      0.000000   0.000000  16.369496
# 1006.0                     44.000000   0.000000  15.574400
# 1018.0                     71.000000  30.000000   6.400000
# 1053.0                     42.454545   0.000000  13.153661
# 1059.0                      0.000000   0.000000  15.006667
# 1071.0                      0.000000   0.000000  10.407987
# 1078.0                      0.000000   0.000000  15.547470
# 1086.0                     51.750000  60.000000  11.298896
# 1087.0                      0.000000   0.000000  14.815909
#
# group                      Restaurant/Takeaway  Roasterie/Tea shop  \
# from_totally_fake_account
# 1000.0                               34.327447           22.726667
# 1002.0                               31.992979           20.606667
# 1006.0                               30.310769           31.360000
# 1018.0                               34.061923           26.365000
# 1053.0                               19.236889           31.817500
# 1059.0                               35.029767           34.015000
# 1071.0                               33.524390           22.120000
# 1078.0                               31.175111           39.090000
# 1086.0                               31.097143           38.033333
# 1087.0                               33.934681           17.273333
#
# group                      Sports store  Streaming service  Supermarket  \
# from_totally_fake_account
# 1000.0                         0.000000               8.99    85.241250
# 1002.0                        87.500000               8.99    95.055455
# 1006.0                         0.000000               8.99    20.693333
# 1018.0                        84.000000               0.00    23.003929
# 1053.0                       115.000000               8.99    86.093846
# 1059.0                        68.666667               0.00    67.843125
# 1071.0                        68.384615               8.99   100.036667
# 1078.0                        80.500000               8.99    90.596557
# 1086.0                       117.000000               8.99    23.457083
# 1087.0                         0.000000               0.00   114.450000
#
# group                      Technology store
# from_totally_fake_account
# 1000.0                                  0.0
# 1002.0                                  0.0
# 1006.0                                  0.0
# 1018.0                                  0.0
# 1053.0                                 79.0
# 1059.0                                  0.0
# 1071.0                                235.5
# 1078.0                                  0.0
# 1086.0                                  0.0
# 1087.0                                  0.0
#
# [10 rows x 25 columns]

# %%
X_train, X_test = train_test_split(per_category, test_size=0.2, random_state=10)

# %%
# loop over values of k from 1 to 10
inertias = []
K = 10
for k in range(1, K+1):
    # instantiate the KMeans class with k clusters
    kmeans = KMeans(n_clusters= k)
    
    # fit the model to the data
    kmeans.fit(X_train)

    # store the value of the inertia for this value of k
    inertias.append(kmeans.inertia_)

plt.figure()
plt.plot(range(1, K+1), inertias, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.title('The elbow method showing the optimal k')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Text(0.5, 1.0, 'The elbow method showing the optimal k')

# %%
# K-means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X_train)

# predict clusters for the test data
test_clusters = kmeans.predict(X_train)

# evaluate the clustering performance
silhouette_avg = silhouette_score(X_train, test_clusters)
print("Silhouette Score:", silhouette_avg)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Silhouette Score: 0.35714627413185474

# %%
# initialize HDBSCAN
clusterer = hdbscan.HDBSCAN()

# fit model
clusterer.fit(X_train)

# predict clusters for the test data
test_clusters = clusterer.fit_predict(X_train)

# evaluate the clusters
silhouette_avg = silhouette_score(X_train, test_clusters)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: -0.22599940285010198

# %%
# count the number of unique cluster labels
num_clusters = len(np.unique(clusterer.labels_)) - 1  # Exclude noise points (-1)
print("Number of clusters identified:", num_clusters)
# Out:
# Number of clusters identified: 15

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_train.iloc[:, 0], X_train.iloc[:, 1], c=test_clusters, cmap='viridis', alpha=0.6)
plt.title("HDBSCAN Clustering Results")
plt.xlabel("First Principal Component")
plt.ylabel("Second Principal Component")
plt.colorbar(label='Cluster Label')
plt.grid(True)
plt.show()
